# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"G:\Uppsala Docs\period5&6\ProcessedData\2015-2019_sensorData.csv",
                 usecols=['Stop','Station Name','PM10'])

# selecting station #Stockholm E4/E20 Lilla Essingen
#df = df[df['Station Name']=='#Stockholm Torkel Knutssongatan']

# Rename Stop to Time
df = df.rename(columns={"Stop": "Timestamp"})

# convert columns to date
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Generating Year, Month and droppng 2020 data
df['Year'] = df['Timestamp'].dt.year

# Test df
test_df = df.loc[df['Year'] ==  2019]
print(test_df.info())
print(test_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96360 entries, 268790 to 450644
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Timestamp     96360 non-null  datetime64[ns]
#  1   Station Name  96360 non-null  object
#  2   PM10          60422 non-null  float64
#  3   Year          96360 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 3.7+ MB
# None
#                PM10     Year
# count  60422.000000  96360.0
# mean      17.901290   2019.0
# std       21.152133      0.0
# min       -3.000000   2019.0
# 25%        6.900000   2019.0
# 50%       11.900000   2019.0
# 75%       20.600000   2019.0
# max      388.500000   2019.0

# %%
# Train df
train_df = df.loc[df['Year'].isin([2015,2016,2017,2018])]
print(train_df.info())
print(train_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354275 entries, 0 to 354284
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Timestamp     354275 non-null  datetime64[ns]
#  1   Station Name  354275 non-null  object
#  2   PM10          206892 non-null  float64
#  3   Year          354275 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 13.5+ MB
# None
#                 PM10           Year
# count  206892.000000  354275.000000
# mean       19.269404    2016.578500
# std        19.533088       1.108678
# min        -3.040000    2015.000000
# 25%         8.400000    2016.000000
# 50%        13.800000    2017.000000
# 75%        22.800000    2018.000000
# max       447.600000    2018.000000

# %%
df.describe()
# Out:
#                 PM10           Year
# count  267321.000000  450646.000000
# mean       18.960425    2017.096364
# std        19.918945       1.397218
# min        -3.040000    2015.000000
# 25%         8.000000    2016.000000
# 50%        13.400000    2017.000000
# 75%        22.400000    2018.000000
# max       447.600000    2020.000000

# %%
# Time Series of Raw data with outliers
pd1 = train_df
pd1 = pd1.set_index("Timestamp")
pd1['PM10'].plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Time Series of Raw data with outliers
pd1 = test_df
pd1 = pd1.set_index("Timestamp")
pd1['PM10'].plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
figsize=(0,10)
# autocorrelation plot for 180 days
f1 = plt.figure(1)
plot_acf(pd1['PM10'].dropna(), lags=4320)
f1.show()
# autocorrelation plot for 1 days
f2 = plt.figure(2)
plot_acf(pd1['PM10'].dropna(), lags=72)
f2.show()
# partialautocorrelation plot for 1 days 
f3 = plt.figure(3)
plot_pacf(pd1['PM10'].dropna(), lags=72)
f3.show()
# Out:
# E:\Programs\Anaconda\envs\damp\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.
# E:\Programs\Anaconda\envs\damp\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## test train separate Normalisation

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

## Modyfying data for traning LSTM 
# selecting PM10 column
data_set  = train_df.iloc[:,2].values
# replace missing values with -1 (later used to mask nan)
nan_index  = np.isnan(data_set)
data_set[np.isnan(data_set)] = -1
print(data_set)
data_set  = data_set.reshape(-1,1)
print("Shape:\n",data_set.shape)
print("Data Set:\n",data_set[0:4])
# Normalisation of Data
sc = MinMaxScaler(feature_range = (0, 1))
data_set_scaled = sc.fit_transform(data_set)
print("Normalised Data Set:\n",data_set_scaled[0:4])
# Generating LSTM featurse with Lag and Y
X_train = []
y_train = []
for i in range(5, len(data_set)):
    X_train.append(data_set_scaled[i-5:i, 0])
    y_train.append(data_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print("X_train:\n",X_train[0:2])
print("y_train:\n",y_train[0:2])
# Out:
# [57.  13.  12.8 ...  7.8  7.4  6.7]
# Shape:
#  (354275, 1)
# Data Set:
#  [[57. ]
#  [13. ]
#  [12.8]
#  [13.9]]
# Normalised Data Set:
#  [[0.13323274]
#  [0.03559382]
#  [0.03515001]
#  [0.03759098]]
# X_train:
#  [[[0.13323274]
#   [0.03559382]
#   [0.03515001]
#   [0.03759098]
#   [0.03803479]]
#
#  [[0.03559382]
#   [0.03515001]
#   [0.03759098]
#   [0.03803479]
#   [0.03870051]]]
# y_train:
#  [0.03870051 0.03625954]

# %%
## Modyfying data for testing LSTM 
# selecting PM10 column
data_set  = test_df.iloc[:,2].values
# replace missing values with -1 (later used to mask nan)
nan_index  = np.isnan(data_set)
data_set[np.isnan(data_set)] = -1
print(data_set)
data_set  = data_set.reshape(-1,1)
print("Shape:\n",data_set.shape)
print("Data Set:\n",data_set[0:4])
# Normalisation of Data
sc = MinMaxScaler(feature_range = (0, 1))
data_set_scaled = sc.fit_transform(data_set)
print("Normalised Data Set:\n",data_set_scaled[0:4])
# Generating LSTM featurse with Lag and Y
X_test = []
y_test = []
for i in range(5, len(data_set)):
    X_test.append(data_set_scaled[i-5:i, 0])
    y_test.append(data_set_scaled[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print("X_test:\n",X_test[0:2])
print("y_test:\n",y_test[0:2])
# Out:
# [7.5 5.7 6.6 ... 4.5 3.  2.8]
# Shape:
#  (96360, 1)
# Data Set:
#  [[ 7.5]
#  [ 5.7]
#  [ 6.6]
#  [-1. ]]
# Normalised Data Set:
#  [[0.02681992]
#  [0.02222222]
#  [0.02452107]
#  [0.00510856]]
# X_test:
#  [[[0.02681992]
#   [0.02222222]
#   [0.02452107]
#   [0.00510856]
#   [0.00510856]]
#
#  [[0.02222222]
#   [0.02452107]
#   [0.00510856]
#   [0.00510856]
#   [0.00510856]]]
# y_test:
#  [0.00510856 0.00510856]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Masking

## LSTM Architecture
# input layer
model = Sequential()
# 1
model.add(Masking(mask_value=-1, input_shape = (X_train.shape[1], 1)))
model.add(LSTM(units = 50, return_sequences = False))
model.add(Dropout(0.2))
# output layer
model.add(Dense(units = 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 5, 1)              0
# _________________________________________________________________
# lstm (LSTM)                  (None, 50)                10400
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
import tensorflow as tf
# Creating an empty Dataframe with column names only
plotData = pd.DataFrame(columns=['Train_Instance','Test_size','Train_RMSE','Test_RMSE'])

# 5% to 100% BY 5%
for i in range(20,101,20):
    
    tf.keras.backend.clear_session()
    
    print(str(i)+' % of the Data')
    train_len = round(X_train.shape[0]*(i/100))
    test_len = X_test.shape[0]
    print('No of train entires: '+str(train_len))
    print('No of test entires: '+str(test_len))
    print("TRAIN:", (0,train_len), "TEST:", (X_train.shape[0],X_train.shape[0]+X_test.shape[0]))
    
    # Compile LSTM Model
    opt = tf.keras.optimizers.Adam(learning_rate=0.01)
    model.compile(optimizer = opt, loss = 'mean_squared_error')
    # Train the model on the data
    model.fit(X_train[0:train_len], y_train[0:train_len], epochs = 5, batch_size = 64)
    
    ## Train RMSE
    # predicting PM10
    predicted_y = model.predict(X_train[0:train_len])
    # De-normalising predicted y data
    predicted_y = sc.inverse_transform(predicted_y)
    # De-normalising actual y data
    y_actual = sc.inverse_transform(y_train[0:train_len].reshape(-1,1))
    # calculating TEST RMSE
    train_rmse = sqrt(mean_squared_error(y_actual, predicted_y))
    print('TRAIN RMSE: '+str(train_rmse))
    
    ## Test RMSE
    # predicting PM10
    predicted_y = model.predict(X_test)
    # De-normalising predicted y data
    predicted_y = sc.inverse_transform(predicted_y)
    # De-normalising actual y data
    y_actual = sc.inverse_transform(y_test.reshape(-1,1))
    # calculating TEST RMSE
    test_rmse = sqrt(mean_squared_error(y_actual, predicted_y))
    print('TEST RMSE: '+str(test_rmse))
    
    # Append rows in Empty Dataframe by adding dictionaries
    plotData = plotData.append({'Train_size':train_len,'Test_size':test_len,'Train_RMSE':train_rmse,'Test_RMSE':test_rmse}, ignore_index=True)
    
    print('\n')
# Out:
# 20 % of the Data
# No of train entires: 70854
# No of test entires: 96355
# TRAIN: (0, 70854) TEST: (354270, 450625)
# Epoch 1/5
# 1108/1108 [==============================] - 26s 24ms/step - loss: 3.3865e-04
# Epoch 2/5
# 1108/1108 [==============================] - 20s 18ms/step - loss: 2.9921e-04
# Epoch 3/5
# 1108/1108 [==============================] - 18s 17ms/step - loss: 2.8342e-04
# Epoch 4/5
# 1108/1108 [==============================] - 18s 16ms/step - loss: 2.8256e-04
# Epoch 5/5
# 1108/1108 [==============================] - 18s 16ms/step - loss: 2.8005e-04
# TRAIN RMSE: 6.625318170070968
# TEST RMSE: 7.717316202512453
#
#
# 40 % of the Data
# No of train entires: 141708
# No of test entires: 96355
# TRAIN: (0, 141708) TEST: (354270, 450625)
# Epoch 1/5
# 2215/2215 [==============================] - 136s 61ms/step - loss: 2.6531e-043s - ETA: 1s -
# Epoch 4/5
# 2215/2215 [==============================] - 121s 54ms/step - loss: 2.6250e-04
# Epoch 5/5
# 2215/2215 [==============================] - 129s 58ms/step - loss: 2.6219e-04
# TRAIN RMSE: 6.146977673339857
# TEST RMSE: 7.5004583338447075
#
#
# 60 % of the Data
# No of train entires: 212562
# No of test entires: 96355
# TRAIN: (0, 212562) TEST: (354270, 450625)
# Epoch 1/5
# 3322/3322 [==============================] - 212s 64ms/step - loss: 2.5965e-04
# Epoch 3/5
# 3322/3322 [==============================] - 100s 30ms/step - loss: 2.6024e-04
# Epoch 4/5
# 3322/3322 [==============================] - 62s 19ms/step - loss: 2.5931e-04
# Epoch 5/5
# 3322/3322 [==============================] - 65s 20ms/step - loss: 2.5839e-04
# TRAIN RMSE: 6.106673768470768
# TEST RMSE: 7.508825573952254
#
#
# 80 % of the Data
# No of train entires: 283416
# No of test entires: 96355
# TRAIN: (0, 283416) TEST: (354270, 450625)
# Epoch 1/5
# 4429/4429 [==============================] - 80s 18ms/step - loss: 2.9868e-04
# Epoch 2/5
# 4429/4429 [==============================] - 99s 22ms/step - loss: 2.9918e-04
# Epoch 3/5
# 4429/4429 [==============================] - 97s 22ms/step - loss: 2.9788e-04
# Epoch 4/5
# 4429/4429 [==============================] - 94s 21ms/step - loss: 2.9832e-04 1s
# Epoch 5/5
# 4429/4429 [==============================] - 79s 18ms/step - loss: 2.9815e-04
# TRAIN RMSE: 6.578320500588943
# TEST RMSE: 7.265937311262584
#
#
# 100 % of the Data
# No of train entires: 354270
# No of test entires: 96355
# TRAIN: (0, 354270) TEST: (354270, 450625)
# Epoch 1/5
# 5536/5536 [==============================] - 102s 18ms/step - loss: 2.8495e-04
# Epoch 2/5
# 5536/5536 [==============================] - 107s 19ms/step - loss: 2.8553e-04
# Epoch 3/5
# 5536/5536 [==============================] - 103s 19ms/step - loss: 2.8487e-04
# Epoch 4/5
# 5536/5536 [==============================] - 103s 19ms/step - loss: 2.8446e-04
# Epoch 5/5
# 5536/5536 [==============================] - 107s 19ms/step - loss: 2.8512e-04 ETA: 0s - loss: 2.8
# TRAIN RMSE: 6.7334549409371895
# TEST RMSE: 7.6491406192377385

# %%
# Plot 
plt.plot(plotData.Train_size,plotData.Train_RMSE,label="Train Error")
plt.plot(plotData.Train_size,plotData.Test_RMSE,label="Test Error")
plt.xlabel('Training Instance')
plt.ylabel('RMSE Value')
plt.legend()
plt.show()

# %% [markdown]
# ## test train normalise together

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

## Modyfying data for traning LSTM 
# selecting PM10 column
data_set  = df.iloc[:,2].values
# replace missing values with -1 (later used to mask nan)
nan_index  = np.isnan(data_set)
data_set[np.isnan(data_set)] = -1
print(data_set)
data_set  = data_set.reshape(-1,1)
print("Shape:\n",data_set.shape)
print("Data Set:\n",data_set[0:4])
# Normalisation of Data
sc = MinMaxScaler(feature_range = (0, 1))
data_set_scaled = sc.fit_transform(data_set)
print("Normalised Data Set:\n",data_set_scaled[0:4])
# Generating LSTM featurse with Lag and Y
X = []
y = []
for i in range(5, len(data_set)):
    X.append(data_set_scaled[i-5:i, 0])
    y.append(data_set_scaled[i, 0])
X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))
print("X:\n",X[0:2])
print("y:\n",y[0:2])
# Out:
# [57.  13.  12.8 ...  3.   2.8  4.6]
# Shape:
#  (450646, 1)
# Data Set:
#  [[57. ]
#  [13. ]
#  [12.8]
#  [13.9]]
# Normalised Data Set:
#  [[0.13323274]
#  [0.03559382]
#  [0.03515001]
#  [0.03759098]]
# X:
#  [[[0.13323274]
#   [0.03559382]
#   [0.03515001]
#   [0.03759098]
#   [0.03803479]]
#
#  [[0.03559382]
#   [0.03515001]
#   [0.03759098]
#   [0.03803479]
#   [0.03870051]]]
# y:
#  [0.03870051 0.03625954]

# %%
X_train = X[0:round(X.shape[0]*0.8)]
X_test = X[round(X.shape[0]*0.8):X.shape[0]]
y_train = y[0:round(y.shape[0]*0.8)]
y_test = y[round(y.shape[0]*0.8):y.shape[0]]

print('X_train',(0,round(X.shape[0]*0.8)),'X_test',(round(X.shape[0]*0.8),X.shape[0]))
print('y_train',(0,round(y.shape[0]*0.8)),'y_test',(round(y.shape[0]*0.8),y.shape[0]))
# Out:
# X_train (0, 360513) X_test (360513, 450641)
# y_train (0, 360513) y_test (360513, 450641)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
import tensorflow as tf
# Creating an empty Dataframe with column names only
plotData = pd.DataFrame(columns=['Train_Instance','Test_size','Train_RMSE','Test_RMSE'])

# 5% to 100% BY 5%
for i in range(20,101,20):
    
    tf.keras.backend.clear_session()
    
    print(str(i)+' % of the Data')
    train_len = round(X_train.shape[0]*(i/100))
    test_len = X_test.shape[0]
    print('No of train entires: '+str(train_len))
    print('No of test entires: '+str(test_len))
    print("TRAIN:", (0,train_len), "TEST:", (X_train.shape[0],X_train.shape[0]+X_test.shape[0]))
    
    # Compile LSTM Model
    opt = tf.keras.optimizers.Adam(learning_rate=0.01)
    model.compile(optimizer = opt, loss = 'mean_squared_error')
    # Train the model on the data
    model.fit(X_train[0:train_len], y_train[0:train_len], epochs = 5, batch_size = 64)
    
    ## Train RMSE
    # predicting PM10
    predicted_y = model.predict(X_train[0:train_len])
    # De-normalising predicted y data
    predicted_y = sc.inverse_transform(predicted_y)
    # De-normalising actual y data
    y_actual = sc.inverse_transform(y_train[0:train_len].reshape(-1,1))
    # calculating TEST RMSE
    train_rmse = sqrt(mean_squared_error(y_actual, predicted_y))
    print('TRAIN RMSE: '+str(train_rmse))
    
    ## Test RMSE
    # predicting PM10
    predicted_y = model.predict(X_test)
    # De-normalising predicted y data
    predicted_y = sc.inverse_transform(predicted_y)
    # De-normalising actual y data
    y_actual = sc.inverse_transform(y_test.reshape(-1,1))
    # calculating TEST RMSE
    test_rmse = sqrt(mean_squared_error(y_actual, predicted_y))
    print('TEST RMSE: '+str(test_rmse))
    
    # Append rows in Empty Dataframe by adding dictionaries
    plotData = plotData.append({'Train_size':train_len,'Test_size':test_len,'Train_RMSE':train_rmse,'Test_RMSE':test_rmse}, ignore_index=True)
    
    print('\n')
# Out:
# 20 % of the Data
# No of train entires: 72103
# No of test entires: 90128
# TRAIN: (0, 72103) TEST: (360513, 450641)
# Epoch 1/5
# 1127/1127 [==============================] - 20s 18ms/step - loss: 2.6604e-04
# Epoch 2/5
# 1127/1127 [==============================] - 21s 18ms/step - loss: 2.6524e-04
# Epoch 3/5
# 1127/1127 [==============================] - 20s 18ms/step - loss: 2.6560e-04
# Epoch 4/5
# 1127/1127 [==============================] - 20s 18ms/step - loss: 2.6656e-04
# Epoch 5/5
# 1127/1127 [==============================] - 21s 18ms/step - loss: 2.6476e-04
# TRAIN RMSE: 7.224158179974356
# TEST RMSE: 7.160013182424684
#
#
# 40 % of the Data
# No of train entires: 144205
# No of test entires: 90128
# TRAIN: (0, 144205) TEST: (360513, 450641)
# Epoch 1/5
# 2254/2254 [==============================] - 40s 18ms/step - loss: 2.8798e-04 0s - loss: 2.8
# Epoch 2/5
# 2254/2254 [==============================] - 39s 17ms/step - loss: 2.8783e-04
# Epoch 3/5
# 2254/2254 [==============================] - 40s 18ms/step - loss: 2.8752e-04
# Epoch 4/5
# 2254/2254 [==============================] - 40s 18ms/step - loss: 2.8659e-04
# Epoch 5/5
# 2254/2254 [==============================] - 41s 18ms/step - loss: 2.8832e-04
# TRAIN RMSE: 7.395955425816976
# TEST RMSE: 6.723062230517848
#
#
# 60 % of the Data
# No of train entires: 216308
# No of test entires: 90128
# TRAIN: (0, 216308) TEST: (360513, 450641)
# Epoch 1/5
# 3380/3380 [==============================] - 71s 21ms/step - loss: 2.5285e-04
# Epoch 2/5
# 3380/3380 [==============================] - 59s 18ms/step - loss: 2.5163e-04
# Epoch 3/5
# 3380/3380 [==============================] - 63s 19ms/step - loss: 2.5177e-04
# Epoch 4/5
# 3380/3380 [==============================] - 60s 18ms/step - loss: 2.5100e-04 0s - loss: 2.5
# Epoch 5/5
# 3380/3380 [==============================] - 61s 18ms/step - loss: 2.5177e-04
# TRAIN RMSE: 7.104187493204541
# TEST RMSE: 6.851730703084162
#
#
# 80 % of the Data
# No of train entires: 288410
# No of test entires: 90128
# TRAIN: (0, 288410) TEST: (360513, 450641)
# Epoch 1/5
# 4507/4507 [==============================] - 80s 18ms/step - loss: 2.9133e-04
# Epoch 2/5
# 4507/4507 [==============================] - 81s 18ms/step - loss: 2.9165e-04
# Epoch 3/5
# 4507/4507 [==============================] - 81s 18ms/step - loss: 2.9024e-04
# Epoch 4/5
# 4507/4507 [==============================] - 81s 18ms/step - loss: 2.9174e-04
# Epoch 5/5
# 4507/4507 [==============================] - 80s 18ms/step - loss: 2.9310e-04
# TRAIN RMSE: 7.480036904188841
# TEST RMSE: 6.746403520801501
#
#
# 100 % of the Data
# No of train entires: 360513
# No of test entires: 90128
# TRAIN: (0, 360513) TEST: (360513, 450641)
# Epoch 1/5
# 5634/5634 [==============================] - 102s 18ms/step - loss: 2.9152e-04
# Epoch 2/5
# 5634/5634 [==============================] - 101s 18ms/step - loss: 2.9246e-04
# Epoch 3/5
# 5634/5634 [==============================] - 100s 18ms/step - loss: 2.9321e-04
# Epoch 4/5
# 5634/5634 [==============================] - 101s 18ms/step - loss: 2.9382e-04
# Epoch 5/5
# 5634/5634 [==============================] - 104s 18ms/step - loss: 2.9114e-04
# TRAIN RMSE: 8.132478768364079
# TEST RMSE: 7.424937192683032

# %%
# Plot 
plt.plot(plotData.Train_size,plotData.Train_RMSE,label="Train Error")
plt.plot(plotData.Train_size,plotData.Test_RMSE,label="Test Error")
plt.xlabel('Training Instance')
plt.ylabel('RMSE Value')
plt.legend()
plt.show()

# %%
## splitting data into test and train
# len of the 
# td_percentage = 0.20
# test_size = int(len(X)*td_percentage)

# # segmenting 2018 may data
# start_date = '2018-01-01 00:00:00'
# end_date  = '2018-10-31 23:59:59'
# df_2 = df[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date)]
# # Data distribution Across Stations in 2015 month
# print('Data distribution Across Stations:')
# print(df_2.groupby(['Station Name']).aggregate(
#     'count').drop(['Timestamp','Classification'],1))
# df_2.groupby(['Station Name']).aggregate(
#     'count').drop(['Timestamp','Classification'],1).plot(figsize = (15,10),grid=True,subplots=True)

# X_train = X[0:X.shape[0]-test_size]
# y_train = y[0:X.shape[0]-test_size]
# X_test = X[0:test_size]
# y_test = y[0:test_size]

# print("X_train_shape:\n",X_train.shape)
# print("y_train_shape:\n",y_train.shape)
# print("X_test_shape:\n",X_test.shape)
# print("y_test_shape:\n",y_test.shape)

# %%
# # Train the model on the data
# model.fit(X_train, y_train, epochs = 10, batch_size = 128)

# %%
# from sklearn.metrics import mean_squared_error
# from math import sqrt

# # predicting PM10
# predicted_y = model.predict(X_test)
# # De-normalising predicted y data
# predicted_y = sc.inverse_transform(predicted_y)
# # De-normalising actual y data
# y_actual = sc.inverse_transform(y_test.reshape(-1,1))
# # calculating RMSE
# rmse = sqrt(mean_squared_error(y_actual, predicted_y))
# rmse

# %%
# y_actual[0:15]

# %%
# predicted_y[0:15]

# %%
# plt.figure(figsize=(20,10))
# plt.plot(y_actual, color = 'black', label = 'PM10 Actual')
# plt.plot(predicted_y, color = 'red', label = 'PM10 Predicted')
# plt.title('PM10 Actual vs Predicted')
# plt.xlabel('Time')
# plt.ylabel('ug/m3')
# plt.legend()
# plt.show()

# %%
# model.save(r'G:\Uppsala Docs\period5&6\Models')
