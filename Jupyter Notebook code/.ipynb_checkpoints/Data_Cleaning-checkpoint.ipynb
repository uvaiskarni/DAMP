# %%
import os
import re
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sensorData = pd.read_csv(r"G:\Uppsala Docs\period5&6\ProcessedData\sensorData.csv")
sensorData.head()
# Out:
#    Unnamed: 0                Start                 Stop  \
# 0           0  2019-01-01 00:00:00  2019-01-01 01:00:00
# 1           1  2019-01-01 01:00:00  2019-01-01 02:00:00
# 2           2  2019-01-01 02:00:00  2019-01-01 03:00:00
# 3           3  2019-01-01 03:00:00  2019-01-01 04:00:00
# 4           4  2019-01-01 04:00:00  2019-01-01 05:00:00
#
#                   Station Name   NO2  NOX as NO2  PM2.5  CO  Black Carbon  O3  \
# 0  #Stockholm St Eriksgatan 83  13.0        22.7   21.4 NaN           NaN NaN
# 1  #Stockholm St Eriksgatan 83  10.5        17.1    8.3 NaN           NaN NaN
# 2  #Stockholm St Eriksgatan 83   6.1        12.5    3.4 NaN           NaN NaN
# 3  #Stockholm St Eriksgatan 83   4.0         8.6    2.5 NaN           NaN NaN
# 4  #Stockholm St Eriksgatan 83   6.5        10.4    3.2 NaN           NaN NaN
#
#    National Station Code  Longitude  Latitude Classification  PM10
# 0                 157992  18.037016   59.3405  Urban Traffic  31.5
# 1                 157992  18.037016   59.3405  Urban Traffic  12.6
# 2                 157992  18.037016   59.3405  Urban Traffic   5.4
# 3                 157992  18.037016   59.3405  Urban Traffic   3.9
# 4                 157992  18.037016   59.3405  Urban Traffic   5.5

# %%
sensorData = sensorData.drop('Unnamed: 0',1) # drop unwanted column
sensorData.head()
# Out:
#                  Start                 Stop                 Station Name  \
# 0  2019-01-01 00:00:00  2019-01-01 01:00:00  #Stockholm St Eriksgatan 83
# 1  2019-01-01 01:00:00  2019-01-01 02:00:00  #Stockholm St Eriksgatan 83
# 2  2019-01-01 02:00:00  2019-01-01 03:00:00  #Stockholm St Eriksgatan 83
# 3  2019-01-01 03:00:00  2019-01-01 04:00:00  #Stockholm St Eriksgatan 83
# 4  2019-01-01 04:00:00  2019-01-01 05:00:00  #Stockholm St Eriksgatan 83
#
#     NO2  NOX as NO2  PM2.5  CO  Black Carbon  O3  National Station Code  \
# 0  13.0        22.7   21.4 NaN           NaN NaN                 157992
# 1  10.5        17.1    8.3 NaN           NaN NaN                 157992
# 2   6.1        12.5    3.4 NaN           NaN NaN                 157992
# 3   4.0         8.6    2.5 NaN           NaN NaN                 157992
# 4   6.5        10.4    3.2 NaN           NaN NaN                 157992
#
#    Longitude  Latitude Classification  PM10
# 0  18.037016   59.3405  Urban Traffic  31.5
# 1  18.037016   59.3405  Urban Traffic  12.6
# 2  18.037016   59.3405  Urban Traffic   5.4
# 3  18.037016   59.3405  Urban Traffic   3.9
# 4  18.037016   59.3405  Urban Traffic   5.5

# %%
sensorData.describe()
# Out:
#                 NO2    NOX as NO2         PM2.5            CO  Black Carbon  \
# count  94567.000000  94688.000000  40803.000000  48736.000000  17210.000000
# mean      23.192400     44.836990      5.973700      0.323945      0.550013
# std       19.168868     51.487473      4.863483      0.236738      0.548290
# min        0.100000      0.500000     -3.000000      0.000000      0.010000
# 25%        8.800000     11.500000      2.700000      0.200000      0.196250
# 50%       17.400000     25.700000      4.700000      0.300000      0.397000
# 75%       32.400000     59.300000      7.800000      0.400000      0.751000
# max      169.900000    707.900000     71.200000     18.600000     30.400000
#
#                 O3  National Station Code     Longitude      Latitude  \
# count  8511.000000           96360.000000  96360.000000  96360.000000
# mean     54.925214           54084.545455     18.045615     59.325836
# std      23.418629           64049.067821      0.021659      0.011685
# min       2.000000            8779.000000     18.004040     59.313300
# 25%      38.500000            8781.000000     18.037016     59.316006
# 50%      54.400000           18640.000000     18.049046     59.317223
# 75%      70.100000          157992.000000     18.058254     59.340828
# max     143.700000          159403.000000     18.077139     59.341076
#
#                PM10
# count  60422.000000
# mean      17.903624
# std       21.153849
# min       -3.000000
# 25%        6.900000
# 50%       11.900000
# 75%       20.600000
# max      388.500000

# %%
# convert columns to date
sensorData['Start'] = pd.to_datetime(sensorData['Start'])
sensorData['Stop'] = pd.to_datetime(sensorData['Stop'])
sensorData.dtypes
# Out:
# Start                    datetime64[ns]
# Stop                     datetime64[ns]
# Station Name                     object
# NO2                             float64
# NOX as NO2                      float64
# PM2.5                           float64
# CO                              float64
# Black Carbon                    float64
# O3                              float64
# National Station Code             int64
# Longitude                       float64
# Latitude                        float64
# Classification                   object
# PM10                            float64
# dtype: object

# %%
# percentage of columns that are not empty
total = sensorData.isnull().sum().sort_values(ascending = False)
total = total[sensorData.isnull().sum().sort_values(ascending = False) != 0]
percent =  100 - total / len(sensorData) * 100
percent[sensorData.isnull().sum().sort_values(ascending = False) != 0].plot.bar(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
# Average Gas Emission per hour based on station
sensorData.groupby('Station Name').mean()[['NO2', 'NOX as NO2', 'PM2.5','Black Carbon', 'O3','PM10']].plot.bar(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Station Name'>

# %%
df_pollutants = sensorData[['Start','NO2', 'NOX as NO2', 'PM2.5','Black Carbon', 'O3','PM10']]
df_pollutants = df_pollutants.set_index("Start")
df_pollutants.index = pd.to_datetime(df_pollutants.index, unit='s')
df_pollutants = df_pollutants.dropna()
df_pollutants_resample = df_pollutants.resample(rule = "M").mean().ffill()
df_pollutants_resample.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Start'>

# %%
df_pollutants_resample
# Out:
#                   NO2  NOX as NO2     PM2.5  Black Carbon         O3  \
# Start
# 2019-04-30  13.086876   15.128466  8.769501      0.562595  88.863586
# 2019-05-31  11.127785   13.932737  4.500138      0.307334  66.233975
# 2019-06-30   7.171742    9.059590  4.505417      0.279806  72.071449
# 2019-07-31   6.759684    8.895839  3.205882      0.244459  53.031564
# 2019-08-31   6.847865    8.237189  4.687722      0.304624  59.453025
# 2019-09-30  10.079393   11.745527  3.625879      0.333722  49.036422
# 2019-10-31  11.311636   13.515852  3.571838      0.294345  39.420742
# 2019-11-30   9.875915   11.738451  7.250845      0.549182  32.699859
# 2019-12-31  10.455510   12.138776  4.856054      0.434092  40.757959
#
#                  PM10
# Start
# 2019-04-30  23.899630
# 2019-05-31  12.427235
# 2019-06-30  11.737921
# 2019-07-31   6.812052
# 2019-08-31   9.635409
# 2019-09-30   8.714058
# 2019-10-31   7.601180
# 2019-11-30   9.124085
# 2019-12-31   6.552245

# %% [markdown]
# ### Features Selection

# %% [markdown]
# #### 1.Univariate Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# spliting in features and labels   
#X = sensorData.iloc[:,0:12].select_dtypes(include = ['float'])  #independent columns
X = sensorData[['NO2', 'NOX as NO2', 'PM2.5','PM10']]
y = sensorData.iloc[:,-1]
X.columns
# Out:
# Index(['NO2', 'NOX as NO2', 'PM2.5', 'PM10'], dtype='object')

# %%
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-00e2cb8003a5> in <module>
#       1 #apply SelectKBest class to extract top 10 best features
#       2 bestfeatures = SelectKBest(score_func=chi2, k=10)
# ----> 3 fit = bestfeatures.fit(X,y)
#       4 dfscores = pd.DataFrame(fit.scores_)
#       5 dfcolumns = pd.DataFrame(X.columns)
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     343         """
#     344         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
# --> 345                                    multi_output=True)
#     346
#     347         if not callable(self.score_func):
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# #### 2. Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

# %%
# spliting in features and labels   
X = sensorData.iloc[:,0:12].select_dtypes(include = ['float'])  #independent columns
y = sensorData.iloc[:,-1]
X.columns
# Out:
# Index(['NO2', 'NOX as NO2', 'PM2.5', 'CO', 'Black Carbon', 'O3', 'Longitude',
#        'Latitude'],
#       dtype='object')

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-73c9bc1f3611> in <module>
#       1 model = ExtraTreesClassifier()
# ----> 2 model.fit(X,y)
#       3 print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#       4 #plot graph of feature importances for better visualization
#       5 feat_importances = pd.Series(model.feature_importances_, index=X.columns)
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# E:\Programs\Anaconda\envs\damp\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %% [markdown]
# #### 3.Correlation Matrix with Heatmap

# %%
import seaborn as sns

# %%
# spliting in features and labels   
X = sensorData.iloc[:,0:12].select_dtypes(include = ['float'])  #independent columns
y = sensorData.iloc[:,-1]
X.columns
# Out:
# Index(['NO2', 'NOX as NO2', 'PM2.5', 'CO', 'Black Carbon', 'O3', 'Longitude',
#        'Latitude'],
#       dtype='object')

# %%
#get correlations of each features in dataset
corrmat = sensorData.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(sensorData[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
# Out:
# O3              91.167497
# Black Carbon    82.139892
# PM2.5           57.655666
# CO              49.422997
# PM10            37.295558
# NO2              1.860731
# NOX as NO2       1.735160
# dtype: float64
