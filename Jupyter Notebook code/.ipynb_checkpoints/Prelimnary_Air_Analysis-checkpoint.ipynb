# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read data into required segments
# #### 1. Station Details
# #### 2. Sensor Air Constitute Details

# %%
metaData1 = pd.read_csv(r"G:\Uppsala Docs\period5&6\ProcessedData\metaData1.csv")
metaData1.head(3)
# Out:
#    Unnamed: 0                #Stationsnamn  Nationell stationskod  \
# 0           0  #Stockholm St Eriksgatan 83                 157992
# 1           1   #Stockholm E4 Skonertvägen                 157993
# 2           2  #Stockholm Folkungagatan 70                 159403
#
#   Klassificering   Longitud  Latitud,,,
# 0  Urban Traffic  18.037016  59.3405,,,
# 1  Urban Traffic  18.004040  59.3133,,,
# 2  Urban Traffic  18.077139  59.3146,,,

# %%
metaData2 = pd.read_csv(r"G:\Uppsala Docs\period5&6\ProcessedData\metaData2.csv")
metaData2.head(3)
# Out:
#    Unnamed: 0        #Ämne            Ämnesbeskrivning   Enhet  Mäthöjd  \
# 0           0         #NO2            Nitrogen dioxide  ug.m-3      3.0
# 1           1  #NOX as NO2             Nitrogen oxides  ug.m-3      3.0
# 2           2        #PM10  Particulate matter < 10 µm  ug.m-3      3.0
#
#   Inlet-id,,,                #Stationsnamn  Nationell stationskod  \
# 0     4204,,,  #Stockholm St Eriksgatan 83                 157992
# 1     4205,,,  #Stockholm St Eriksgatan 83                 157992
# 2     4206,,,  #Stockholm St Eriksgatan 83                 157992
#
#   Klassificering   Longitud  Latitud,,,
# 0  Urban Traffic  18.037016  59.3405,,,
# 1  Urban Traffic  18.037016  59.3405,,,
# 2  Urban Traffic  18.037016  59.3405,,,

# %%
sensorData = pd.read_csv(r"G:\Uppsala Docs\period5&6\ProcessedData\sensorData.csv")
sensorData.head(3)
# Out:
#    Unnamed: 0                Start                 Stop  \
# 0           0  2019-01-01 00:00:00  2019-01-01 01:00:00
# 1           1  2019-01-01 01:00:00  2019-01-01 02:00:00
# 2           2  2019-01-01 02:00:00  2019-01-01 03:00:00
#
#                   Station Name   NO2  NOX as NO2  PM2.5  CO  Black Carbon  O3  \
# 0  #Stockholm St Eriksgatan 83  13.0        22.7   21.4 NaN           NaN NaN
# 1  #Stockholm St Eriksgatan 83  10.5        17.1    8.3 NaN           NaN NaN
# 2  #Stockholm St Eriksgatan 83   6.1        12.5    3.4 NaN           NaN NaN
#
#    National Station Code  Longitude  Latitude Classification  PM10
# 0                 157992  18.037016   59.3405  Urban Traffic  31.5
# 1                 157992  18.037016   59.3405  Urban Traffic  12.6
# 2                 157992  18.037016   59.3405  Urban Traffic   5.4

# %%
sensorData.describe()
# Out:
#          Unnamed: 0           NO2    NOX as NO2         PM2.5            CO  \
# count  96360.000000  94567.000000  94688.000000  40803.000000  48736.000000
# mean   40215.863636     23.192400     44.836990      5.973700      0.323945
# std    26652.554619     19.168868     51.487473      4.863483      0.236738
# min        0.000000      0.100000      0.500000     -3.000000      0.000000
# 25%    15329.750000      8.800000     11.500000      2.700000      0.200000
# 50%    39419.500000     17.400000     25.700000      4.700000      0.300000
# 75%    63509.250000     32.400000     59.300000      7.800000      0.400000
# max    87599.000000    169.900000    707.900000     71.200000     18.600000
#
#        Black Carbon           O3  National Station Code     Longitude  \
# count  17210.000000  8511.000000           96360.000000  96360.000000
# mean       0.550013    54.925214           54084.545455     18.045615
# std        0.548290    23.418629           64049.067821      0.021659
# ...

# %%
sensorData.dtypes
# Out:
# Unnamed: 0                 int64
# Start                     object
# Stop                      object
# Station Name              object
# NO2                      float64
# NOX as NO2               float64
# PM2.5                    float64
# CO                       float64
# Black Carbon             float64
# O3                       float64
# National Station Code      int64
# Longitude                float64
# Latitude                 float64
# Classification            object
# PM10                     float64
# dtype: object

# %% [markdown]
# ### Outlier Analysis
# #### 1.Box plot
# #### 2.Histgram
# #### 3.Distribution of Data

# %%
sensorData[['NO2','NOX as NO2','PM10','PM2.5','CO','Black Carbon','O3']].boxplot(grid=False, rot=45, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
sensorData[['NO2','NOX as NO2','PM10','PM2.5','CO','Black Carbon','O3']].hist(grid=False, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'NO2'}>,
#         <AxesSubplot:title={'center':'NOX as NO2'}>,
#         <AxesSubplot:title={'center':'PM10'}>],
#        [<AxesSubplot:title={'center':'PM2.5'}>,
#         <AxesSubplot:title={'center':'CO'}>,
#         <AxesSubplot:title={'center':'Black Carbon'}>],
#        [<AxesSubplot:title={'center':'O3'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sensorData[['NO2','NOX as NO2','PM10','PM2.5','CO','Black Carbon','O3']].hist(bins=100, grid=False, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'NO2'}>,
#         <AxesSubplot:title={'center':'NOX as NO2'}>,
#         <AxesSubplot:title={'center':'PM10'}>],
#        [<AxesSubplot:title={'center':'PM2.5'}>,
#         <AxesSubplot:title={'center':'CO'}>,
#         <AxesSubplot:title={'center':'Black Carbon'}>],
#        [<AxesSubplot:title={'center':'O3'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(sensorData[['NO2','NOX as NO2','PM10','PM2.5','CO','Black Carbon','O3']], diag_kind="kde", 
             plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})
